# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage.transform import resize
from skimage.io import imread

from solcore.structure import Junction
from solcore.solar_cell import SolarCell
from solcore.light_source import LightSource
from solcore.spice import solve_quasi_3D
# Out:
# 	Welcome to Solcore - version 5.5.2
# 	Copyright (c) 2018, Imperial College London. All rights reserved.
# 	Software released under the GNU Lesser General Public License.
#
# WARNING: The RCWA solver will not be available because an S4 installation has not been found.
# WARNING: The Poisson - Drift-Diffusion solver will not be available because the ddModel fortran library could not be imported.
# No module named 'solcore.poisson_drift_diffusion.ddModel'

# %%
profile_file="Illumination profile_20180926.png"

# %%
img=imread(profile_file)

# %%
img.shape
# Out:
# (201, 201, 3)

# %%
img[0,0,:]
# Out:
# array([2, 2, 2], dtype=uint8)

# %%
plt.imshow(img)

# %% [markdown]
# randomize the file to protect the data

# %%
randomized_mtx=np.random.randint(1,100,size=(img.shape[0],img.shape[1]))

# %%
np.savetxt('Illumination profile_20180926_random.csv',randomized_mtx.astype(np.uint),delimiter=',',fmt='%d')

# %%
unit_photon=1.1426e11

# %%
from pypvcell.spectrum import Spectrum
from pypvcell.illumination import load_astm

# %%
sp=load_astm("AM1.5d")

# %%
x,y=sp.get_spectrum(to_x_unit='eV',to_photon_flux=True)

# %%
plt.plot(x,y)

# %% [markdown]
# Total one-sun photons per m^2

# %%
total_one_sun_photons=np.trapz(y,x)
print(total_one_sun_photons)
# Out:
# 3.987799969257739e+21

# %%
pixel_photon_unit=1.1426e11

# %% [markdown]
# Calculate photon number per m^2

# %%
pixel_photon_unit/(5e-6*5e-6)
# Out:
# 4.5703999999999995e+21
